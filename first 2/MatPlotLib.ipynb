# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
x=np.random.random([20])
y=np.random.random([20])
a=np.random.random([20])
b=np.random.random([20])
x,y,a,b
# Out:
# (array([0.97622647, 0.66067278, 0.27990677, 0.77709429, 0.51206898,
#         0.00173614, 0.34717816, 0.05871682, 0.02789182, 0.024221  ,
#         0.1841505 , 0.45775499, 0.387228  , 0.61742496, 0.22227847,
#         0.52682374, 0.28879398, 0.05704715, 0.72170644, 0.73914917]),
#  array([0.78253617, 0.35532706, 0.3401296 , 0.27381006, 0.36553548,
#         0.38606141, 0.41401372, 0.72538589, 0.43221402, 0.54835194,
#         0.70523949, 0.03454302, 0.15217026, 0.75684345, 0.75640589,
#         0.53082466, 0.33412006, 0.45844968, 0.55437809, 0.39046629]),
#  array([0.07888794, 0.39511463, 0.50440571, 0.77158565, 0.49559228,
#         0.1786271 , 0.39462871, 0.19555212, 0.41026442, 0.28286097,
#         0.39758022, 0.74774908, 0.29922996, 0.60591499, 0.64042617,
#         0.83205695, 0.58785538, 0.34048197, 0.75296785, 0.72700059]),
#  array([0.94186145, 0.70703656, 0.86524717, 0.43168991, 0.80598622,
#         0.77263495, 0.07636416, 0.20690606, 0.63813161, 0.77048442,
# ...

# %%
plt.plot(x,y, color='r',label="yumyel")
plt.plot(a,b, color='b',label="belu")
plt.xlabel("x")
plt.ylabel("y")
plt.legend(loc='best')

# %%
x = np.arange(start=0, stop=20, step=0.1)
plt.plot(np.cos(x),color="red")
plt.plot(np.sin(x),color="blue")
plt.plot(np.tan(x)/50,color="yellow")

# %%
class vehicle:
    def __init__(self, wheels, color, airbags, sunroof):
        self.wheels=wheels
        self.color=color
        self.airbags=airbags
        self.sunroof=sunroof
        
    def start(self):
        print("Gaadi bhagreli")
        
    def stop(self):
        print("Maama dikha palti maar")
        
bmw = vehicle(4,"|red",True,True)
bmw.start()
bmw.stop()
# Out:
# Gaadi bhagreli
# Maama dikha palti maar

# %% [markdown]
# $$J(\theta)=\frac{1}{2n}\sum_{i=0}^n (h_\theta(x^i) - y^i)^2$$
