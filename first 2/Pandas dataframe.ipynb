# %%
import pandas as p
import numpy as np
from matplotlib import pyplot as plt

# %%
x = p.Series(["Gatka","Pochinki","MilitiaryBase","Rozhok","Severny"])
y = p.Series([i for i in range(10) if i%2!=0])
x,y
# Out:
# (0            Gatka
#  1         Pochinki
#  2    MilitiaryBase
#  3           Rozhok
#  4          Severny
#  dtype: object, 0    1
#  1    3
#  2    5
#  3    7
#  4    9
#  dtype: int64)

# %%
dataframe = p.DataFrame({"x":x,"y":y})
dataframe["ratings"] = [3,4,3,4,5]
dataframe
# Out:
#                x  y  ratings
# 0          Gatka  1        3
# 1       Pochinki  3        4
# 2  MilitiaryBase  5        3
# 3         Rozhok  7        4
# 4        Severny  9        5

# %%
dataframe = p.DataFrame(
    data=[["ek","do"],["teen","chaar"]],
    columns=["zero","one"],
    index=["two","three"]
)
dataframe
# Out:
#        zero    one
# two      ek     do
# three  teen  chaar

# %%
dataframe = p.DataFrame(
    
    data=[{"m416":50,"M16A":30,"AKM":40,"Scar-L":82},
          {"m416":40,"M16A":20,"AKM":20,"Scar-L":27},
          {"m416":30,"M16A":50,"AKM":50,"Scar-L":47},
          {"m416":50,"M16A":30,"AKM":60,"Scar-L":67}
         ],
    index=["Pochinki","Rozhok","Severny","Milibase"]
)
dataframe
# Out:
#           AKM  M16A  Scar-L  m416
# Pochinki   40    30      82    50
# Rozhok     20    20      27    40
# Severny    50    50      47    30
# Milibase   60    30      67    50

# %%
from sklearn.datasets import load_boston

boston = load_boston()
boston
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %%
dataframe = p.DataFrame(

    data=boston.data,
    columns=boston.feature_names
    
)
dataframe
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0  242.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0  311.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0  311.0
# ...

# %%
dataframe['price']=boston.target
dataframe
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0  242.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0  311.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0  311.0
# ...

# %%
dataframe.head(5)
dataframe.tail(5)
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  price
# 501     21.0  391.99   9.67   22.4
# 502     21.0  396.90   9.08   20.6
# 503     21.0  396.90   5.64   23.9
# 504     21.0  393.45   6.48   22.0
# 505     21.0  396.90   7.88   11.9

# %%
dataframe.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
dataframe.iloc[0:10,0:15]
dataframe.iloc[1]
# Out:
# CRIM         0.02731
# ZN           0.00000
# INDUS        7.07000
# CHAS         0.00000
# NOX          0.46900
# RM           6.42100
# AGE         78.90000
# DIS          4.96710
# RAD          2.00000
# TAX        242.00000
# PTRATIO     17.80000
# B          396.90000
# LSTAT        9.14000
# price       21.60000
# Name: 1, dtype: float64

# %%
dataframe[dataframe.loc[:,"price"]==12.6]
# Out:
#         CRIM   ZN  INDUS  CHAS   NOX     RM   AGE    DIS   RAD    TAX  \
# 447  9.92485  0.0   18.1   0.0  0.74  6.251  96.6  2.198  24.0  666.0
#
#      PTRATIO       B  LSTAT  price
# 447     20.2  388.52  16.44   12.6

# %%
dataframe[["price","ZN"]]
# Out:
#      price    ZN
# 0     24.0  18.0
# 1     21.6   0.0
# 2     34.7   0.0
# 3     33.4   0.0
# 4     36.2   0.0
# 5     28.7   0.0
# 6     22.9  12.5
# 7     27.1  12.5
# 8     16.5  12.5
# 9     18.9  12.5
# 10    15.0  12.5
# 11    18.9  12.5
# 12    21.7  12.5
# 13    20.4   0.0
# 14    18.2   0.0
# 15    19.9   0.0
# 16    23.1   0.0
# 17    17.5   0.0
# 18    20.2   0.0
# 19    18.2   0.0
# 20    13.6   0.0
# 21    19.6   0.0
# 22    15.2   0.0
# 23    14.5   0.0
# 24    15.6   0.0
# 25    13.9   0.0
# 26    16.6   0.0
# 27    14.8   0.0
# 28    18.4   0.0
# 29    21.0   0.0
# ..     ...   ...
# 476   16.7   0.0
# 477   12.0   0.0
# 478   14.6   0.0
# 479   21.4   0.0
# 480   23.0   0.0
# 481   23.7   0.0
# 482   25.0   0.0
# 483   21.8   0.0
# 484   20.6   0.0
# 485   21.2   0.0
# 486   19.1   0.0
# 487   20.6   0.0
# 488   15.2   0.0
# 489    7.0   0.0
# 490    8.1   0.0
# 491   13.6   0.0
# 492   20.1   0.0
# 493   21.8   0.0
# 494   24.5   0.0
# 495   23.1   0.0
# ...
